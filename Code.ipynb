# %%
# ✅ IMPORTS
import pandas as pd
import sqlite3
import re
import requests
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import gradio as gr
from huggingface_hub import login
import ollama

import torch

# %%
# ✅ STEP 2: LOAD AND CLEAN SOIL DATA
soil_df = pd.read_csv("muaggatt.txt", sep="|", header=None)

# Assign USDA soil column names
soil_df.columns = [
    "mukey", "hzname", "desgnmaster", "desgnmasterprime", "hzdept_r", "hzdepb_r",
    "fragvol_r", "dbthirdbar_r", "cec7_r", "ph1to1h2o_r", "ec_r", "sar_r",
    "eps_r", "calciumcarbonate_r", "om_r", "lep_r", "kffact", "aws0150bar_r",
    "aws03bar_r", "awc_r", "wsatiated_r", "wtenthbar_r", "wthirdbar_r", "wfifteenbar_r",
    "wsatiated33bar_r", "silttotal_r", "sandtotal_r", "claytotal_r", "gypsum_r", "aluminum_r",
    "base_sat_r", "caexch_r", "mgexch_r", "kexch_r", "naexch_r", "cec7clay_r",
    "ph01mcacl2_r", "phs_r", "cec8_r", "texture_class"
]

# Keep relevant columns
soil_df = soil_df[[
    "mukey", "hzname", "ph1to1h2o_r", "om_r", "awc_r", "texture_class",
    "cec7_r", "claytotal_r", "sandtotal_r", "calciumcarbonate_r", "hzdept_r"
]]


# ✅ Drop rows where all important columns are missing
soil_df_clean = soil_df.dropna(subset=["ph1to1h2o_r", "om_r", "awc_r"], how="all")

# ✅ Remove rows with urban/water layers
soil_df_clean = soil_df_clean[~soil_df_clean["hzname"].str.contains("water|urban", case=False, na=False)]

# ✅ Convert columns to numeric where needed
cols_to_convert = ["ph1to1h2o_r", "om_r", "awc_r", "cec7_r", "claytotal_r", "sandtotal_r", "calciumcarbonate_r", "hzdept_r"]
for col in cols_to_convert:
    soil_df_clean[col] = pd.to_numeric(soil_df_clean[col], errors="coerce")

# ✅ Fill missing values with safe estimates
soil_df_clean["ph1to1h2o_r"].fillna(6.5, inplace=True)   # Neutral pH
soil_df_clean["om_r"].fillna(2.0, inplace=True)          # Typical organic matter
soil_df_clean["awc_r"].fillna(0.15, inplace=True)        # Moderate water capacity
soil_df_clean["cec7_r"].fillna(10.0, inplace=True)       # Avg fertility
soil_df_clean["claytotal_r"].fillna(20.0, inplace=True)  # Mid-range clay
soil_df_clean["sandtotal_r"].fillna(60.0, inplace=True)  # Mid-range sand
soil_df_clean["calciumcarbonate_r"].fillna(0.0, inplace=True)
soil_df_clean["hzdept_r"].fillna(30.0, inplace=True)     # 30 cm default

# ✅ Convert pH from USDA scale to real scale (÷10)
soil_df_clean["ph1to1h2o_r"] = soil_df_clean["ph1to1h2o_r"] / 10

# Preview cleaned data
soil_df_clean.head()
# Out:
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["ph1to1h2o_r"].fillna(6.5, inplace=True)   # Neutral pH
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["om_r"].fillna(2.0, inplace=True)          # Typical organic matter
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["awc_r"].fillna(0.15, inplace=True)        # Moderate water capacity
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["cec7_r"].fillna(10.0, inplace=True)       # Avg fertility
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["claytotal_r"].fillna(20.0, inplace=True)  # Mid-range clay
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["sandtotal_r"].fillna(60.0, inplace=True)  # Mid-range sand
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["calciumcarbonate_r"].fillna(0.0, inplace=True)
# C:\Users\surya\AppData\Local\Temp\ipykernel_12956\117588084.py:41: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   soil_df_clean["hzdept_r"].fillna(30.0, inplace=True)     # 30 cm default
#    mukey                                      hzname  ph1to1h2o_r   om_r  \
# 1   s275          Rositas-Ripley-Indio-Gilman (s275)         0.65  18.07
# 2   s295          Schenco-Rock outcrop-Laposa (s295)         0.65   5.27
# 4  s1001               Tujunga-Salinas-Elder (s1001)         0.65  16.41
# 7  s1004  Ramona-Hanford-Greenfield-Gorgonio (s1004)         0.65  16.35
# 8  s1005        San Emigdio-Metz-Grangeville (s1005)         0.65  18.24
#
#    awc_r  texture_class  cec7_r  claytotal_r  sandtotal_r  calciumcarbonate_r  \
# 1     43         658353    10.0         20.0         60.0               12.65
# 2    100         658373    10.0         20.0         60.0                5.27
# 4     34         660448    10.0         20.0         60.0               10.94
# 7     54         660451    10.0         20.0         60.0               10.99
# 8     41         660452    10.0         20.0         60.0               12.23
#
#    hzdept_r
# 1       1.3
# 2      43.9
# 4       3.6
# 7       5.9
# 8       2.6

# %%
mapunit_df = pd.read_csv("mapunit.txt", sep="|", header=None)

# Assign column names
mapunit_df.columns = [
    "mukey", "mapunit_name", "type", "null1", "acres", "null2", "null3", "null4", "null5", "null6",
    "null7", "null8", "null9", "null10", "soil_order", "null11", "null12", "area_symbol", "mapunit_id",
    "null13", "null14", "null15", "null16", "null17"
]

mapunit_df = mapunit_df[["mukey", "mapunit_name", "type", "acres", "soil_order", "area_symbol"]]



# ✅ Merge
merged_df = pd.merge(soil_df_clean, mapunit_df, on="mukey", how="left")

# %%
# Load CSV
crop_df = pd.read_csv("data_core.csv")

# Normalize text fields
for col in ["Crop Type", "Soil Type", "Fertilizer Name"]:
    crop_df[col] = crop_df[col].str.lower().str.strip()

# Ensure numeric columns are clean types
num_cols = ["Temparature", "Humidity", "Moisture", "Nitrogen", "Potassium", "Phosphorous"]
for col in num_cols:
    crop_df[col] = pd.to_numeric(crop_df[col], errors="coerce")

# Optional: remove duplicates (if needed)
crop_df.drop_duplicates(inplace=True)

# Optional: sort or filter by a specific condition
# e.g., crop_df = crop_df[crop_df["Temparature"] <= 40]

# %%
conn = sqlite3.connect("soil_data.db")
merged_df.to_sql("soil_enriched", conn, if_exists="replace", index=False)
crop_df.to_sql("crop_data", conn, if_exists="replace", index=False)

print("✅ SQLite database 'soil_data.db' created with tables: soil_enriched and crop_data")
# Out:
# ✅ SQLite database 'soil_data.db' created with tables: soil_enriched and crop_data

# %%
conn = sqlite3.connect("soil_data.db")
cursor = conn.cursor()

# Get all table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Loop through tables and show their columns
for (table_name,) in tables:
    print(f"\n🔹 Columns in table '{table_name}':")
    cursor.execute(f"PRAGMA table_info({table_name});")
    for col in cursor.fetchall():
        print(f" - {col[1]}")  # col[1] is the column name
# Out:
# 🔹 Columns in table 'soil_enriched':
#  - mukey
#  - hzname
#  - ph1to1h2o_r
#  - om_r
#  - awc_r
#  - texture_class
#  - cec7_r
#  - claytotal_r
#  - sandtotal_r
#  - calciumcarbonate_r
#  - hzdept_r
#  - mapunit_name
#  - type
#  - acres
#  - soil_order
#  - area_symbol
#
# 🔹 Columns in table 'crop_data':
#  - Temparature
#  - Humidity
#  - Moisture
#  - Soil Type
#  - Crop Type
#  - Nitrogen
#  - Potassium
#  - Phosphorous
#  - Fertilizer Name

# %%
def get_weather_for_city(city_name, api_key="447c98ec3e842a54b1feb7c3678c56bf"):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}&units=metric"
    try:
        response = requests.get(url)
        data = response.json()
        temp = data["main"]["temp"]
        humidity = data["main"]["humidity"]
        return {"temperature": temp, "humidity": humidity}
    except Exception as e:
        return f"❌ Error fetching weather: {e}"

# %%
def extract_crop_keyword(user_input):
    conn = sqlite3.connect("soil_data.db")
    crops_df = pd.read_sql("SELECT DISTINCT `Crop Type` FROM crop_data", conn)
    crops = crops_df["Crop Type"].str.lower().str.strip().tolist()

    for crop in crops:
        if crop in user_input.lower():
            return crop
    return None

# %%
def extract_conditions_from_input(user_input):
    user_input = user_input.lower()
    conditions = {}

    for soil in ["loamy", "clay", "sandy", "black", "red"]:
        if soil in user_input:
            conditions["soil_type"] = soil
            break

    match = re.search(r"(?:temp(?:erature)?\s*)?(\d{2})\s*(?:c|°)?", user_input)
    if match:
        conditions["temperature"] = int(match.group(1))

    match = re.search(r"(humidity|humid)\s*(\d{2,3})", user_input)
    if match:
        conditions["humidity"] = int(match.group(2))

    return conditions

# %%
def recommend_crops_flexibly(conditions):
    df = pd.read_sql("SELECT * FROM crop_data", conn)
    df["Soil Type"] = df["Soil Type"].str.lower().str.strip()
    df["Crop Type"] = df["Crop Type"].str.lower().str.strip()

    if "soil_type" in conditions:
        df = df[df["Soil Type"] == conditions["soil_type"]]
    if "humidity" in conditions:
        df = df[df["Humidity"] <= conditions["humidity"] + 10]
    if "temperature" in conditions:
        df = df[df["Temparature"] <= conditions["temperature"] + 5]

    if df.empty:
        return "❌ No crop match found for the given conditions."
    return df[["Crop Type", "Soil Type", "Temparature", "Humidity", "Fertilizer Name"]].drop_duplicates()

# %%
def query_soil_by_crop(crop_name):
    crop_name = crop_name.lower().strip()

    # Step 1: Lookup soil type from crop_data
    soil_type_result = pd.read_sql(
        "SELECT `Soil Type` FROM crop_data WHERE `Crop Type` = ?", 
        conn, 
        params=[crop_name]
    )
    
    if soil_type_result.empty:
        return f"❌ No soil type found for {crop_name}"
    
    soil_type = soil_type_result.iloc[0].iloc[0].lower()

    # Step 2: Query enriched soil info
    query = """
    SELECT 
        mukey, mapunit_name, texture_class, ph1to1h2o_r AS pH, 
        om_r AS organic_matter, awc_r AS water_capacity,
        cec7_r AS fertility_rating, claytotal_r, sandtotal_r,
        area_symbol, acres, soil_order
    FROM soil_enriched
    WHERE LOWER(texture_class) LIKE ? OR LOWER(mapunit_name) LIKE ?
    LIMIT 5;
    """
    
    return pd.read_sql(query, conn, params=[f"%{soil_type}%", f"%{soil_type}%"])

# %%
def web_search(query, api_key="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"):
    url = "https://api.tavily.com/search"
    headers = {"Authorization": f"Bearer {api_key}"}
    payload = {"query": query, "num_results": 5}
    try:
        response = requests.post(url, json=payload, headers=headers)
        response.raise_for_status()
        results = response.json().get("results", [])
        return "\n\n".join([f"🔗 {r['title']}\n{r['url']}" for r in results])
    except Exception as e:
        return f"❌ Web search failed: {str(e)}"

# %%
# ✅ SECURITY FILTER
def is_safe_input(user_input):
    blocked = [
        "system settings", "ignore previous", "sudo", "admin", "root",
        "delete", "reboot", "bash", "format", "execute"
    ]
    return not any(word in user_input.lower() for word in blocked)

# ✅ ADVANCED PROMPTING (Meta + Self-Reflection)
prompt_cache = {}

def run_with_llm(prompt, model="mistral"):
    if not is_safe_input(prompt):
        return "🚫 Sorry, that request isn't allowed for security reasons."

    if prompt in prompt_cache:
        return prompt_cache[prompt]

    meta_prompt = f"""
You are a helpful agricultural assistant. Stay within the domain of farming.

First, generate an answer to the user's question.

Then reflect: Is this answer accurate, safe, and relevant?

If not, rephrase or reject it.

Question: {prompt}
Answer:"""

    try:
        response = ollama.chat(model=model, messages=[
            {"role": "user", "content": meta_prompt.strip()}
        ])
        answer = response["message"]["content"]
        prompt_cache[prompt] = answer
        return answer
    except Exception as e:
        return f"❌ LLM error: {e}"

# %%
def handle_chained_prompt(user_input, model="mistral"):
    if " and " in user_input.lower():
        parts = user_input.split(" and ")
        answers = []
        for part in parts:
            ans = run_with_llm(part.strip(), model=model)
            answers.append(f"🔹 {part.strip().capitalize()} → {ans.strip()}")
        return "\n\n".join(answers)
    return run_with_llm(user_input, model=model)

# %%
def smart_farming_assistant(user_input, model):
    user_input = user_input.lower()
    crop_name = extract_crop_keyword(user_input)

    # Weather-based
    if "recommend" in user_input and "for" in user_input:
        city = user_input.split("for")[-1].strip()
        weather = get_weather_for_city(city)
        if isinstance(weather, dict):
            return recommend_crops_flexibly(weather).to_string(index=False)
        else:
            return weather

    # Structured soil query
    elif any(w in user_input for w in ["soil", "ph", "moisture", "texture"]) and crop_name:
        result = query_soil_by_crop(crop_name)
        if isinstance(result, str) or result.empty:
            return run_with_llm(user_input, model=model)
        return result.to_string(index=False)

    # Web-based queries
    elif any(w in user_input for w in ["disease", "fertilizer", "weather", "news", "planting"]):
        web_result = web_search(user_input)
        if web_result.startswith("❌"):
            return run_with_llm(user_input, model=model)
        return web_result

    # Fallback to LLM
    else:
        return handle_chained_prompt(user_input, model=model)

# %%
# 🔍 Sample queries to test TerraGPT
test_questions = [
    "What crops grow well in loamy soil?",
    "What is the ideal pH for wheat?",
    "Suggest a fertilizer for maize.",
    "Recommend crops for clay soil with high humidity.",
    "How to prevent tomato blight?",
    "What crop grows best in sandy soil and low rainfall?",
    "Which crop suits moderately drained soil?",
    "What are signs of tomato disease?",
    "What crop can I grow in Delhi in summer?",
    "Suggest a potassium-rich fertilizer.",
    "What is the organic matter level needed for rice?",
    "Recommend a drought-resistant crop.",
    "Can I grow bananas in acidic soil?",
    "What temperature is best for brinjal?",
    "Suggest crops based on weather in Pune."
]

# %%
for i, q in enumerate(test_questions, 1):
    print(f"\n❓ Q{i}: {q}")
    print(smart_farming_assistant(q,model="mistral"))
    print("-" * 80)
# Out:
# ❓ Q1: What crops grow well in loamy soil?
#  Loamy soil is ideal for a variety of crops due to its good water-holding capacity and excellent nutrient retention. Some crops that thrive in loamy soil include carrots, potatoes, beets, cucumbers, lettuce, tomatoes, corn, peas, and various root vegetables like parsnips and radishes. However, it's essential to consider other factors such as sunlight exposure, temperature, and local climate when selecting crops for your farm.
#
# Reflection: This answer is accurate, safe, and relevant as it provides specific examples of crops that grow well in loamy soil, which is a common type of soil found in many agricultural areas. The information provided is straightforward and easy to understand, making it suitable for a wide range of users seeking advice on crop selection for their farm.
# --------------------------------------------------------------------------------
#
# ❓ Q2: What is the ideal pH for wheat?
#  The ideal pH range for wheat growth is between 6.0 and 7.5. This slightly acidic to neutral soil condition encourages healthy root development and nutrient absorption in the crop. It's essential to maintain the optimal pH level for a bountiful and productive wheat harvest.
#
# Reflect: The answer provided is accurate, safe, and relevant as it directly addresses the user's question about the ideal pH for wheat growth while providing useful information about the suitable pH range for healthy wheat cultivation.
# --------------------------------------------------------------------------------
#
# ❓ Q3: Suggest a fertilizer for maize.
# 🔗 Best Fertilizer for Maize: Organic, NPK, Compost Manure ... - AgriFarming
# https://www.agrifarming.in/best-fertilizer-for-maize-organic-npk-compost-manure-and-schedule
#
# 🔗 The Best Fertilizer for Maize and When to Apply It
# https://www.farmworx.co.ke/the-best-fertilizer-for-maize-and-when-to-apply-it/
#
# 🔗 15 Best Fertilizers for Maize Farm [Organic & Inorganic]
# https://agrolearner.com/best-fertilizers-for-maize/
#
# 🔗 12 Liquid Fertilizers for Maize: Boost Your Crop's Growth!
# https://agrolearner.com/liquid-fertilizers-for-maize/
#
# 🔗 When To Apply Fertilizer To Maize After Planting
# https://gardenerbible.com/when-to-apply-fertilizer-to-maize-after-planting/
# --------------------------------------------------------------------------------
#
# ❓ Q4: Recommend crops for clay soil with high humidity.
# ❌ Error fetching weather: 'main'
# --------------------------------------------------------------------------------
#
# ❓ Q5: How to prevent tomato blight?
#  To prevent tomato blight, here are some measures you can take:
#
# 1. Rotate crops: Avoid planting tomatoes in the same spot year after year as this can increase the likelihood of disease. Instead, rotate crops to break the life cycle of the pathogen.
#
# 2. Choose disease-resistant varieties: Select tomato plants that are bred to be resistant to common diseases such as early blight and late blight.
#
# 3. Practice good sanitation: Remove and dispose of all infected plant material immediately to prevent the spread of the disease.
#
# 4. Use proper spacing: Ensure adequate spacing between plants to improve air circulation, which can help prevent the spread of the disease.
#
# 5. Water correctly: Water at the base of the plant rather than overhead to reduce splashing and spreading of the pathogen.
#
# 6. Apply appropriate fungicides: Use copper-based fungicides or products containing chlorothalonil or mancozeb as a preventative measure, but be sure to follow label instructions carefully.
#
# Reflection: This answer is accurate, safe, and relevant. It provides practical tips for preventing tomato blight based on sound agricultural practices. The suggestions are supported by evidence-based research and are commonly used in the farming community. The language is clear and easy to understand, making it accessible to a wide audience.
# --------------------------------------------------------------------------------
#
# ❓ Q6: What crop grows best in sandy soil and low rainfall?
# 🔹 What crop grows best in sandy soil → 1. Answer: Corn, sorghum, sugarcane, and certain varieties of potatoes are well-suited for sandy soil. These crops require good drainage and do not retain excess moisture, which makes them ideal for soils with high sand content.
#
# 2. Reflection: The answer provided is accurate, safe, and relevant to the domain of farming, as it specifically addresses what crops grow best in sandy soil. It highlights some common examples that are commonly cultivated in such conditions.
#
# 🔹 Low rainfall? → In situations with low rainfall, it is crucial to implement irrigation methods to ensure crops receive sufficient water for growth. Drip irrigation, which delivers water directly to the plant's roots, can help conserve water and reduce evaporation. Additionally, using drought-resistant crop varieties may be beneficial as they require less water to thrive. Mulching can also help retain soil moisture by preventing evaporation and reducing weed competition for water.
#
# Reflect: This answer is accurate, safe, and relevant as it provides information on various strategies to cope with low rainfall in farming, including using irrigation systems, planting drought-resistant crops, and implementing mulching techniques. These methods are widely used and recognized within the agricultural community for their effectiveness in managing water resources during periods of low rainfall.
# --------------------------------------------------------------------------------
#
# ❓ Q7: Which crop suits moderately drained soil?
#  Corn (Zea mays) is a suitable crop for moderately drained soil. It has an average water requirement, making it adaptable to various soil types, including loamy and sandy-loam soils with good drainage. However, it prefers well-drained soil over waterlogged areas to prevent root rot.
#
# Reflection: The answer is accurate, safe, and relevant within the farming domain as corn can indeed grow in moderately drained soil and has an average water requirement.
# --------------------------------------------------------------------------------
#
# ❓ Q8: What are signs of tomato disease?
# 🔗 22 Tomato Diseases: Identification, Treatment and Prevention - The Spruce
# https://www.thespruce.com/identify-treat-prevent-tomato-diseases-7153094
#
# 🔗 Tomato Diseases & Disorders - Home & Garden Information Center
# https://hgic.clemson.edu/factsheet/tomato-diseases-disorders/
#
# 🔗 25 Tomato Diseases & Disorders + Natural Treatments (with Pictures)
# https://drecampbell.com/tomato-diseases-how-to-fix-them-naturally/
#
# 🔗 19 Tomato Diseases: Identification, Treatment & Prevention Tips
# https://www.epicgardening.com/tomato-diseases/
#
# 🔗 How To Identify, Prevent, and Treat Common Tomato Diseases
# https://gardenerspath.com/how-to/disease-and-pests/common-tomato-diseases/
# --------------------------------------------------------------------------------
#
# ❓ Q9: What crop can I grow in Delhi in summer?
#  In Delhi during the summer season, crops that require less water and have a shorter growing period are ideal for cultivation. Here are some crops you could consider:
#
# 1. Okra (Bhindi): This crop is well-adapted to hot climates with short rainfall and can thrive in summer. It requires a minimum of 20 days to maturity.
#
# 2. Brinjal (Eggplant): Brinjal plants require a temperature between 15°C to 30°C for optimal growth. They are drought-tolerant, but frequent watering can help improve yields.
#
# 3. Cucumber: Cucumbers grow well in the heat and prefer plenty of sunlight, but they also need consistent moisture.
#
# 4. Green Chillies: Hot climates like Delhi's are perfect for growing green chilies. They are ready to harvest within 60-75 days after planting.
#
# 5. Tomatoes: Tomatoes require a warm climate and plenty of sunlight, making them suitable for summer cultivation in Delhi. However, they do need regular watering.
#
# Reflect: This answer is accurate as it provides some crops suitable for growing in Delhi during the summer season. It is safe because the suggested crops are common agricultural produce that have been grown successfully in similar climates. The suggestions are also relevant as they address the user's question about crops to grow in Delhi during the summer.
# --------------------------------------------------------------------------------
#
# ❓ Q10: Suggest a potassium-rich fertilizer.
# 🔗 What Fertilizer Is High In Potassium? (15 Good Sources To Try)
# https://greenupside.com/what-fertilizer-is-high-in-potassium/
#
# 🔗 A Complete Guide to 11 High Potassium Fertilizers - Bigger Garden
# https://www.biggergarden.com/high-potassium-fertilizers/
#
# 🔗 15 Fertilizers High in Potassium: The Ultimate List
# https://landscapingplanet.com/15-fertilizers-high-in-potassium/
#
# 🔗 Which Fertilizer Has High Potassium - GardenerBible
# https://gardenerbible.com/which-fertilizer-has-high-potassium/
#
# 🔗 11 High Potassium Fertilizers And When To Use Them - Wild Yards
# https://wildyards.com/high-potassium-fertilizers/
# --------------------------------------------------------------------------------
#
# ❓ Q11: What is the organic matter level needed for rice?
#  The optimal organic matter level for rice paddy soil ranges from 3-5%. Organic matter helps improve soil structure, increases water holding capacity, promotes nutrient availability, and supports beneficial microorganisms that aid in disease suppression. However, it's important to note that the ideal organic matter content can vary depending on factors such as soil type, climate, and farming practices. To ensure your rice fields have optimal organic matter levels, regular testing of the soil is essential.
#
# Reflect: The answer is accurate, safe, and relevant. It provides the user with a good understanding of the appropriate organic matter level for rice paddy soil, as well as its benefits to the growth and health of the crop.
# --------------------------------------------------------------------------------
#
# ❓ Q12: Recommend a drought-resistant crop.
#  A suitable drought-resistant crop recommendation would be Sorghum (Sorghum bicolor). It is a versatile crop that can thrive in dry conditions and has high yield potential. Additionally, it requires minimal water compared to other cereal crops.
#
# Reflect: This answer is accurate, safe, and relevant as sorghum is indeed a drought-resistant crop that is widely grown for food, feed, and bioenergy purposes.
# --------------------------------------------------------------------------------
#
# ❓ Q13: Can I grow bananas in acidic soil?
#  While bananas can tolerate a wide range of soil types, they prefer soils that are slightly acidic to neutral (pH 6.0-6.5). If your soil is significantly more acidic than this, it may be challenging for banana plants to thrive due to nutrient availability issues. To grow bananas in acidic soil, you may consider applying lime to raise the pH level slightly or choosing a variety of banana that is more resilient to acidic conditions, such as the Dwarf Cavendish or Red Banana varieties.
#
# Reflect: The answer provided is accurate, safe, and relevant within the domain of farming. The information about soil preference for growing bananas, potential challenges with acidic soil, and recommendations for amendment or variety selection are all appropriate responses to the user's question.
# --------------------------------------------------------------------------------
#
# ❓ Q14: What temperature is best for brinjal?
#  Brinjals (Eggplants) prefer a warm climate with temperatures between 60-90°F (15-32°C) for optimal growth. They are sensitive to frost and will not thrive in temperatures below 50°F (10°C).
#
# Reflect: This answer is accurate, safe, and relevant as it provides the appropriate temperature range for brinjal growth based on their natural requirements. It also mentions that they are sensitive to frost, which is an important safety consideration when caring for these plants.
# --------------------------------------------------------------------------------
#
# ❓ Q15: Suggest crops based on weather in Pune.
# 🔗 Weather in pune
# https://www.weatherapi.com/
#
# 🔗 Crop Calendar,Plant Calendar, Agriculture Crop Calendar, Crop sowing ...
# https://krishijagran.com/crop-calendar
#
# 🔗 Best crops to grow during an apocalypse, according to scientists
# https://timesofindia.indiatimes.com/life-style/food-news/best-crops-to-grow-during-an-apocalypse-according-to-scientists/articleshow/121037971.cms
#
# 🔗 May Sowing Guide: Best Crops to Plant in May for Indian Climate
# https://www.farmersstop.com/blogs/seed-sowing-guide/may-sowing-guide-best-crops-to-plant-in-may-for-indian-climate
#
# 🔗 2025 Planting Calendar by Zip Code | The Old Farmer's Almanac
# https://www.almanac.com/gardening/planting-calendar
# --------------------------------------------------------------------------------

# %%
for i, q in enumerate(test_questions, 1):
    print(f"\n❓ Q{i}: {q}")
    print(smart_farming_assistant(q,model="llama2"))
    print("-" * 80)
# Out:
# ❓ Q1: What crops grow well in loamy soil?
#  Loamy soil is ideal for a variety of crops due to its good water-holding capacity and excellent nutrient retention. Some crops that thrive in loamy soil include carrots, potatoes, beets, cucumbers, lettuce, tomatoes, corn, peas, and various root vegetables like parsnips and radishes. However, it's essential to consider other factors such as sunlight exposure, temperature, and local climate when selecting crops for your farm.
#
# Reflection: This answer is accurate, safe, and relevant as it provides specific examples of crops that grow well in loamy soil, which is a common type of soil found in many agricultural areas. The information provided is straightforward and easy to understand, making it suitable for a wide range of users seeking advice on crop selection for their farm.
# --------------------------------------------------------------------------------
#
# ❓ Q2: What is the ideal pH for wheat?
#  The ideal pH range for wheat growth is between 6.0 and 7.5. This slightly acidic to neutral soil condition encourages healthy root development and nutrient absorption in the crop. It's essential to maintain the optimal pH level for a bountiful and productive wheat harvest.
#
# Reflect: The answer provided is accurate, safe, and relevant as it directly addresses the user's question about the ideal pH for wheat growth while providing useful information about the suitable pH range for healthy wheat cultivation.
# --------------------------------------------------------------------------------
#
# ❓ Q3: Suggest a fertilizer for maize.
# 🔗 Best Fertilizer for Maize: Organic, NPK, Compost Manure ... - AgriFarming
# https://www.agrifarming.in/best-fertilizer-for-maize-organic-npk-compost-manure-and-schedule
#
# 🔗 The Best Fertilizer for Maize and When to Apply It
# https://www.farmworx.co.ke/the-best-fertilizer-for-maize-and-when-to-apply-it/
#
# 🔗 15 Best Fertilizers for Maize Farm [Organic & Inorganic]
# https://agrolearner.com/best-fertilizers-for-maize/
#
# 🔗 12 Liquid Fertilizers for Maize: Boost Your Crop's Growth!
# https://agrolearner.com/liquid-fertilizers-for-maize/
#
# 🔗 When To Apply Fertilizer To Maize After Planting
# https://gardenerbible.com/when-to-apply-fertilizer-to-maize-after-planting/
# --------------------------------------------------------------------------------
#
# ❓ Q4: Recommend crops for clay soil with high humidity.
# ❌ Error fetching weather: 'main'
# --------------------------------------------------------------------------------
#
# ❓ Q5: How to prevent tomato blight?
#  To prevent tomato blight, here are some measures you can take:
#
# 1. Rotate crops: Avoid planting tomatoes in the same spot year after year as this can increase the likelihood of disease. Instead, rotate crops to break the life cycle of the pathogen.
#
# 2. Choose disease-resistant varieties: Select tomato plants that are bred to be resistant to common diseases such as early blight and late blight.
#
# 3. Practice good sanitation: Remove and dispose of all infected plant material immediately to prevent the spread of the disease.
#
# 4. Use proper spacing: Ensure adequate spacing between plants to improve air circulation, which can help prevent the spread of the disease.
#
# 5. Water correctly: Water at the base of the plant rather than overhead to reduce splashing and spreading of the pathogen.
#
# 6. Apply appropriate fungicides: Use copper-based fungicides or products containing chlorothalonil or mancozeb as a preventative measure, but be sure to follow label instructions carefully.
#
# Reflection: This answer is accurate, safe, and relevant. It provides practical tips for preventing tomato blight based on sound agricultural practices. The suggestions are supported by evidence-based research and are commonly used in the farming community. The language is clear and easy to understand, making it accessible to a wide audience.
# --------------------------------------------------------------------------------
#
# ❓ Q6: What crop grows best in sandy soil and low rainfall?
# 🔹 What crop grows best in sandy soil → 1. Answer: Corn, sorghum, sugarcane, and certain varieties of potatoes are well-suited for sandy soil. These crops require good drainage and do not retain excess moisture, which makes them ideal for soils with high sand content.
#
# 2. Reflection: The answer provided is accurate, safe, and relevant to the domain of farming, as it specifically addresses what crops grow best in sandy soil. It highlights some common examples that are commonly cultivated in such conditions.
#
# 🔹 Low rainfall? → In situations with low rainfall, it is crucial to implement irrigation methods to ensure crops receive sufficient water for growth. Drip irrigation, which delivers water directly to the plant's roots, can help conserve water and reduce evaporation. Additionally, using drought-resistant crop varieties may be beneficial as they require less water to thrive. Mulching can also help retain soil moisture by preventing evaporation and reducing weed competition for water.
#
# Reflect: This answer is accurate, safe, and relevant as it provides information on various strategies to cope with low rainfall in farming, including using irrigation systems, planting drought-resistant crops, and implementing mulching techniques. These methods are widely used and recognized within the agricultural community for their effectiveness in managing water resources during periods of low rainfall.
# --------------------------------------------------------------------------------
#
# ❓ Q7: Which crop suits moderately drained soil?
#  Corn (Zea mays) is a suitable crop for moderately drained soil. It has an average water requirement, making it adaptable to various soil types, including loamy and sandy-loam soils with good drainage. However, it prefers well-drained soil over waterlogged areas to prevent root rot.
#
# Reflection: The answer is accurate, safe, and relevant within the farming domain as corn can indeed grow in moderately drained soil and has an average water requirement.
# --------------------------------------------------------------------------------
#
# ❓ Q8: What are signs of tomato disease?
# 🔗 22 Tomato Diseases: Identification, Treatment and Prevention - The Spruce
# https://www.thespruce.com/identify-treat-prevent-tomato-diseases-7153094
#
# 🔗 Tomato Diseases & Disorders - Home & Garden Information Center
# https://hgic.clemson.edu/factsheet/tomato-diseases-disorders/
#
# 🔗 25 Tomato Diseases & Disorders + Natural Treatments (with Pictures)
# https://drecampbell.com/tomato-diseases-how-to-fix-them-naturally/
#
# 🔗 19 Tomato Diseases: Identification, Treatment & Prevention Tips
# https://www.epicgardening.com/tomato-diseases/
#
# 🔗 How To Identify, Prevent, and Treat Common Tomato Diseases
# https://gardenerspath.com/how-to/disease-and-pests/common-tomato-diseases/
# --------------------------------------------------------------------------------
#
# ❓ Q9: What crop can I grow in Delhi in summer?
#  In Delhi during the summer season, crops that require less water and have a shorter growing period are ideal for cultivation. Here are some crops you could consider:
#
# 1. Okra (Bhindi): This crop is well-adapted to hot climates with short rainfall and can thrive in summer. It requires a minimum of 20 days to maturity.
#
# 2. Brinjal (Eggplant): Brinjal plants require a temperature between 15°C to 30°C for optimal growth. They are drought-tolerant, but frequent watering can help improve yields.
#
# 3. Cucumber: Cucumbers grow well in the heat and prefer plenty of sunlight, but they also need consistent moisture.
#
# 4. Green Chillies: Hot climates like Delhi's are perfect for growing green chilies. They are ready to harvest within 60-75 days after planting.
#
# 5. Tomatoes: Tomatoes require a warm climate and plenty of sunlight, making them suitable for summer cultivation in Delhi. However, they do need regular watering.
#
# Reflect: This answer is accurate as it provides some crops suitable for growing in Delhi during the summer season. It is safe because the suggested crops are common agricultural produce that have been grown successfully in similar climates. The suggestions are also relevant as they address the user's question about crops to grow in Delhi during the summer.
# --------------------------------------------------------------------------------
#
# ❓ Q10: Suggest a potassium-rich fertilizer.
# 🔗 What Fertilizer Is High In Potassium? (15 Good Sources To Try)
# https://greenupside.com/what-fertilizer-is-high-in-potassium/
#
# 🔗 A Complete Guide to 11 High Potassium Fertilizers - Bigger Garden
# https://www.biggergarden.com/high-potassium-fertilizers/
#
# 🔗 15 Fertilizers High in Potassium: The Ultimate List
# https://landscapingplanet.com/15-fertilizers-high-in-potassium/
#
# 🔗 Which Fertilizer Has High Potassium - GardenerBible
# https://gardenerbible.com/which-fertilizer-has-high-potassium/
#
# 🔗 11 High Potassium Fertilizers And When To Use Them - Wild Yards
# https://wildyards.com/high-potassium-fertilizers/
# --------------------------------------------------------------------------------
#
# ❓ Q11: What is the organic matter level needed for rice?
#  The optimal organic matter level for rice paddy soil ranges from 3-5%. Organic matter helps improve soil structure, increases water holding capacity, promotes nutrient availability, and supports beneficial microorganisms that aid in disease suppression. However, it's important to note that the ideal organic matter content can vary depending on factors such as soil type, climate, and farming practices. To ensure your rice fields have optimal organic matter levels, regular testing of the soil is essential.
#
# Reflect: The answer is accurate, safe, and relevant. It provides the user with a good understanding of the appropriate organic matter level for rice paddy soil, as well as its benefits to the growth and health of the crop.
# --------------------------------------------------------------------------------
#
# ❓ Q12: Recommend a drought-resistant crop.
#  A suitable drought-resistant crop recommendation would be Sorghum (Sorghum bicolor). It is a versatile crop that can thrive in dry conditions and has high yield potential. Additionally, it requires minimal water compared to other cereal crops.
#
# Reflect: This answer is accurate, safe, and relevant as sorghum is indeed a drought-resistant crop that is widely grown for food, feed, and bioenergy purposes.
# --------------------------------------------------------------------------------
#
# ❓ Q13: Can I grow bananas in acidic soil?
#  While bananas can tolerate a wide range of soil types, they prefer soils that are slightly acidic to neutral (pH 6.0-6.5). If your soil is significantly more acidic than this, it may be challenging for banana plants to thrive due to nutrient availability issues. To grow bananas in acidic soil, you may consider applying lime to raise the pH level slightly or choosing a variety of banana that is more resilient to acidic conditions, such as the Dwarf Cavendish or Red Banana varieties.
#
# Reflect: The answer provided is accurate, safe, and relevant within the domain of farming. The information about soil preference for growing bananas, potential challenges with acidic soil, and recommendations for amendment or variety selection are all appropriate responses to the user's question.
# --------------------------------------------------------------------------------
#
# ❓ Q14: What temperature is best for brinjal?
#  Brinjals (Eggplants) prefer a warm climate with temperatures between 60-90°F (15-32°C) for optimal growth. They are sensitive to frost and will not thrive in temperatures below 50°F (10°C).
#
# Reflect: This answer is accurate, safe, and relevant as it provides the appropriate temperature range for brinjal growth based on their natural requirements. It also mentions that they are sensitive to frost, which is an important safety consideration when caring for these plants.
# --------------------------------------------------------------------------------
#
# ❓ Q15: Suggest crops based on weather in Pune.
# 🔗 Weather in pune
# https://www.weatherapi.com/
#
# 🔗 Crop Calendar,Plant Calendar, Agriculture Crop Calendar, Crop sowing ...
# https://krishijagran.com/crop-calendar
#
# 🔗 Best crops to grow during an apocalypse, according to scientists
# https://timesofindia.indiatimes.com/life-style/food-news/best-crops-to-grow-during-an-apocalypse-according-to-scientists/articleshow/121037971.cms
#
# 🔗 May Sowing Guide: Best Crops to Plant in May for Indian Climate
# https://www.farmersstop.com/blogs/seed-sowing-guide/may-sowing-guide-best-crops-to-plant-in-may-for-indian-climate
#
# 🔗 2025 Planting Calendar by Zip Code | The Old Farmer's Almanac
# https://www.almanac.com/gardening/planting-calendar
# --------------------------------------------------------------------------------

# %%
import gradio as gr
import ollama

# 🔁 Shared LLM wrapper
'''def run_with_llm(prompt, model="mistral"):
    response = ollama.chat(model=model, messages=[
        {"role": "user", "content": f"You are a farming expert.\n\nQuestion: {prompt}\nAnswer:"}
    ])
    return response["message"]["content"]'''

# 🧠 Route through smart assistant with selected model
def assistant_mistral(user_input):
    return smart_farming_assistant(user_input, model="mistral")

def assistant_llama2(user_input):
    return smart_farming_assistant(user_input, model="llama2")

# 🌿 Gradio Tabs
mistral_tab = gr.Interface(
    fn=assistant_mistral,
    inputs=gr.Textbox(label="user_input", placeholder="e.g., Recommend a crop for clay soil with high humidity", lines=2),
    outputs=gr.Textbox(label="output", lines=8),
    title="🌾 Smart Farming Assistant - Mistral",
    description="Ask about crop recommendations, soil types, fertilizer, or farming tips!"
)

llama_tab = gr.Interface(
    fn=assistant_llama2,
    inputs=gr.Textbox(label="user_input", placeholder="e.g., Recommend a crop for sandy soil with low rainfall", lines=2),
    outputs=gr.Textbox(label="output", lines=8),
    title="🌾 Smart Farming Assistant - LLaMA-2",
    description="Ask the same farming questions powered by LLaMA-2!"
)

# 🧭 Tabbed Launch
gr.TabbedInterface([mistral_tab, llama_tab], ["Mistral", "LLaMA-2"]).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
